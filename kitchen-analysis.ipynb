# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
path = r"C:\Users\Rudra\Desktop\cloud-kitchen-dashboard\kittchen-pnl-data.xlsx"
df = pd.read_excel(path, header=1)

# %%
df
# Out:
#          MONTH       CITY                     STORE    STATUS ZONE MAPPING  \
# 0     Oct-2023  Ahmedabad              Ramos-Martin  Inactive         West
# 1     Nov-2023  Ahmedabad              Ramos-Martin  Inactive         West
# 2     Dec-2023  Ahmedabad              Ramos-Martin  Inactive         West
# 3     Jan-2024  Ahmedabad              Ramos-Martin  Inactive         West
# 4     Feb-2024  Ahmedabad              Ramos-Martin  Inactive         West
# ...        ...        ...                       ...       ...          ...
# 2095  Nov-2023     Mumbai  Jones, Knight and Rivers    Active         East
# 2096  Dec-2023     Mumbai  Jones, Knight and Rivers    Active         East
# 2097  Jan-2024     Mumbai  Jones, Knight and Rivers    Active         East
# 2098  Feb-2024     Mumbai  Jones, Knight and Rivers    Active         East
# 2099  Mar-2024     Mumbai  Jones, Knight and Rivers    Active         East
#
#       ORDER COUNT  CART SALES    DISCOUNT  NET REVENUE  IDEAL FOOD COST  \
# 0           14270  6554333.68  1163493.98   5434068.17       1763679.62
# 1            8528  2637625.82   636015.27   2146679.55        638415.30
# 2           10798  4364193.67  1283840.18   3188606.71       1085080.58
# 3            7804  3479969.32   854797.46   2734306.33       1180892.50
# 4           10060  4771378.71  1290900.38   3602124.88       1114846.94
# ...           ...         ...         ...          ...              ...
# 2095        12005  3764132.03   650583.53   3236050.77       1368304.24
# 2096        11454  4776944.70   763880.67   4078760.77       1795668.85
# 2097        12568  5683969.21  1386463.66   4378116.35       1815618.84
# 2098        12229  5031251.50   797713.07   4335963.51       2023942.25
# 2099         7955  2422156.10   597663.92   1921713.45        871664.51
#
#       GROSS MARGIN  KITCHEN EBITDA  VARIANCE     REVENUE COHORT  \
# 0       3614747.39      2374914.55  29664.62  INR 20 to 30 lacs
# 1       1414249.00       151761.82  11769.85  INR 20 to 30 lacs
# 2       2036999.44       736811.76  23376.83  INR 30 to 40 lacs
# 3       1451140.55       229924.26  26162.41  INR 20 to 30 lacs
# 4       2394567.16      1114151.65  19944.97  INR 20 to 30 lacs
# ...            ...             ...       ...                ...
# 2095    1749922.82       546305.61  24124.15  More than 40 lacs
# 2096    2208469.29       939926.29  28627.88  INR 30 to 40 lacs
# 2097    2486078.29      1375840.66  11235.39  INR 20 to 30 lacs
# 2098    2208644.82       955765.94  26345.33  More than 40 lacs
# 2099     926452.93      -360347.81  11966.10  INR 20 to 30 lacs
#
#           CM COHORT EBITDA CATEGORY  EBITDA COHORT
# 0         0% to 10%      EBITDA +ve  More than 20%
# 1     More than 30%      EBITDA +ve  More than 20%
# 2         0% to 10%      EBITDA +ve      0% to 10%
# 3         0% to 10%      EBITDA +ve  More than 20%
# 4     More than 30%      EBITDA -ve      0% to 10%
# ...             ...             ...            ...
# 2095      0% to 10%      EBITDA +ve  More than 20%
# 2096      0% to 10%      EBITDA +ve  More than 20%
# 2097     10% to 20%      EBITDA -ve     10% to 20%
# 2098      0% to 10%      EBITDA +ve  More than 20%
# 2099  More than 30%      EBITDA -ve  More than 20%
#
# [2100 rows x 17 columns]

# %%
df['MONTH']
# Out:
# 0       Oct-2023
# 1       Nov-2023
# 2       Dec-2023
# 3       Jan-2024
# 4       Feb-2024
#           ...
# 2095    Nov-2023
# 2096    Dec-2023
# 2097    Jan-2024
# 2098    Feb-2024
# 2099    Mar-2024
# Name: MONTH, Length: 2100, dtype: object

# %%
df[['Month_Name', 'Year']]= df['MONTH'].str.split("-", expand=True)

# %%
print(df.head(3))
# Out:
#       MONTH       CITY         STORE    STATUS ZONE MAPPING  ORDER COUNT  \
# 0  Oct-2023  Ahmedabad  Ramos-Martin  Inactive         West        14270
# 1  Nov-2023  Ahmedabad  Ramos-Martin  Inactive         West         8528
# 2  Dec-2023  Ahmedabad  Ramos-Martin  Inactive         West        10798
#
#    CART SALES    DISCOUNT  NET REVENUE  IDEAL FOOD COST  GROSS MARGIN  \
# 0  6554333.68  1163493.98   5434068.17       1763679.62    3614747.39
# 1  2637625.82   636015.27   2146679.55        638415.30    1414249.00
# 2  4364193.67  1283840.18   3188606.71       1085080.58    2036999.44
#
#    KITCHEN EBITDA  VARIANCE     REVENUE COHORT      CM COHORT EBITDA CATEGORY  \
# 0      2374914.55  29664.62  INR 20 to 30 lacs      0% to 10%      EBITDA +ve
# 1       151761.82  11769.85  INR 20 to 30 lacs  More than 30%      EBITDA +ve
# 2       736811.76  23376.83  INR 30 to 40 lacs      0% to 10%      EBITDA +ve
#
#    EBITDA COHORT Month_Name  Year
# 0  More than 20%        Oct  2023
# 1  More than 20%        Nov  2023
# 2      0% to 10%        Dec  2023
