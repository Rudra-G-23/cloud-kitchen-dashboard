# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
path = r"C:\Users\Rudra\Desktop\cloud-kitchen-dashboard\kittchen-pnl-data.xlsx"
df = pd.read_excel(path, header=1)

# %%
df.shape
# Out:
# (2100, 17)

# %%
df.columns
# Out:
# Index(['MONTH', 'CITY', 'STORE', 'STATUS', 'ZONE MAPPING', 'ORDER COUNT',
#        'CART SALES', 'DISCOUNT', 'NET REVENUE', 'IDEAL FOOD COST',
#        'GROSS MARGIN', 'KITCHEN EBITDA', 'VARIANCE', 'REVENUE COHORT',
#        'CM COHORT', 'EBITDA CATEGORY', 'EBITDA COHORT'],
#       dtype='object')

# %%
df.columns = (df.columns.str.strip().str.upper().str.replace(" ", "_"))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MONTH            2100 non-null   object
#  1   CITY             2100 non-null   object
#  2   STORE            2100 non-null   object
#  3   STATUS           2100 non-null   object
#  4   ZONE_MAPPING     2100 non-null   object
#  5   ORDER_COUNT      2100 non-null   int64
#  6   CART_SALES       2100 non-null   float64
#  7   DISCOUNT         2100 non-null   float64
#  8   NET_REVENUE      2100 non-null   float64
#  9   IDEAL_FOOD_COST  2100 non-null   float64
#  10  GROSS_MARGIN     2100 non-null   float64
#  11  KITCHEN_EBITDA   2100 non-null   float64
#  12  VARIANCE         2100 non-null   float64
#  13  REVENUE_COHORT   2100 non-null   object
#  14  CM_COHORT        2100 non-null   object
#  15  EBITDA_CATEGORY  2100 non-null   object
#  16  EBITDA_COHORT    2100 non-null   object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 279.0+ KB

# %%
df
# Out:
#          MONTH       CITY                     STORE    STATUS ZONE_MAPPING  \
# 0     Oct-2023  Ahmedabad              Ramos-Martin  Inactive         West
# 1     Nov-2023  Ahmedabad              Ramos-Martin  Inactive         West
# 2     Dec-2023  Ahmedabad              Ramos-Martin  Inactive         West
# 3     Jan-2024  Ahmedabad              Ramos-Martin  Inactive         West
# 4     Feb-2024  Ahmedabad              Ramos-Martin  Inactive         West
# ...        ...        ...                       ...       ...          ...
# 2095  Nov-2023     Mumbai  Jones, Knight and Rivers    Active         East
# 2096  Dec-2023     Mumbai  Jones, Knight and Rivers    Active         East
# 2097  Jan-2024     Mumbai  Jones, Knight and Rivers    Active         East
# 2098  Feb-2024     Mumbai  Jones, Knight and Rivers    Active         East
# 2099  Mar-2024     Mumbai  Jones, Knight and Rivers    Active         East
#
#       ORDER_COUNT  CART_SALES    DISCOUNT  NET_REVENUE  IDEAL_FOOD_COST  \
# 0           14270  6554333.68  1163493.98   5434068.17       1763679.62
# 1            8528  2637625.82   636015.27   2146679.55        638415.30
# 2           10798  4364193.67  1283840.18   3188606.71       1085080.58
# 3            7804  3479969.32   854797.46   2734306.33       1180892.50
# 4           10060  4771378.71  1290900.38   3602124.88       1114846.94
# ...           ...         ...         ...          ...              ...
# 2095        12005  3764132.03   650583.53   3236050.77       1368304.24
# 2096        11454  4776944.70   763880.67   4078760.77       1795668.85
# 2097        12568  5683969.21  1386463.66   4378116.35       1815618.84
# 2098        12229  5031251.50   797713.07   4335963.51       2023942.25
# 2099         7955  2422156.10   597663.92   1921713.45        871664.51
#
#       GROSS_MARGIN  KITCHEN_EBITDA  VARIANCE     REVENUE_COHORT  \
# 0       3614747.39      2374914.55  29664.62  INR 20 to 30 lacs
# 1       1414249.00       151761.82  11769.85  INR 20 to 30 lacs
# 2       2036999.44       736811.76  23376.83  INR 30 to 40 lacs
# 3       1451140.55       229924.26  26162.41  INR 20 to 30 lacs
# 4       2394567.16      1114151.65  19944.97  INR 20 to 30 lacs
# ...            ...             ...       ...                ...
# 2095    1749922.82       546305.61  24124.15  More than 40 lacs
# 2096    2208469.29       939926.29  28627.88  INR 30 to 40 lacs
# 2097    2486078.29      1375840.66  11235.39  INR 20 to 30 lacs
# 2098    2208644.82       955765.94  26345.33  More than 40 lacs
# 2099     926452.93      -360347.81  11966.10  INR 20 to 30 lacs
#
#           CM_COHORT EBITDA_CATEGORY  EBITDA_COHORT
# 0         0% to 10%      EBITDA +ve  More than 20%
# 1     More than 30%      EBITDA +ve  More than 20%
# 2         0% to 10%      EBITDA +ve      0% to 10%
# 3         0% to 10%      EBITDA +ve  More than 20%
# 4     More than 30%      EBITDA -ve      0% to 10%
# ...             ...             ...            ...
# 2095      0% to 10%      EBITDA +ve  More than 20%
# 2096      0% to 10%      EBITDA +ve  More than 20%
# 2097     10% to 20%      EBITDA -ve     10% to 20%
# 2098      0% to 10%      EBITDA +ve  More than 20%
# 2099  More than 30%      EBITDA -ve  More than 20%
#
# [2100 rows x 17 columns]

# %%
df['MONTH']
# Out:
# 0       Oct-2023
# 1       Nov-2023
# 2       Dec-2023
# 3       Jan-2024
# 4       Feb-2024
#           ...
# 2095    Nov-2023
# 2096    Dec-2023
# 2097    Jan-2024
# 2098    Feb-2024
# 2099    Mar-2024
# Name: MONTH, Length: 2100, dtype: object

# %%
df[['MONTH_NAME', 'YEAR']]= df['MONTH'].str.split("-", expand=True)

# %%
df.head(2)
# Out:
#       MONTH       CITY         STORE    STATUS ZONE_MAPPING  ORDER_COUNT  \
# 0  Oct-2023  Ahmedabad  Ramos-Martin  Inactive         West        14270
# 1  Nov-2023  Ahmedabad  Ramos-Martin  Inactive         West         8528
#
#    CART_SALES    DISCOUNT  NET_REVENUE  IDEAL_FOOD_COST  GROSS_MARGIN  \
# 0  6554333.68  1163493.98   5434068.17       1763679.62    3614747.39
# 1  2637625.82   636015.27   2146679.55        638415.30    1414249.00
#
#    KITCHEN_EBITDA  VARIANCE     REVENUE_COHORT      CM_COHORT EBITDA_CATEGORY  \
# 0      2374914.55  29664.62  INR 20 to 30 lacs      0% to 10%      EBITDA +ve
# 1       151761.82  11769.85  INR 20 to 30 lacs  More than 30%      EBITDA +ve
#
#    EBITDA_COHORT MONTH_NAME  YEAR
# 0  More than 20%        Oct  2023
# 1  More than 20%        Nov  2023

# %%
df['GM'] = df['GROSS_MARGIN']
df['GM_%'] = ( df['GM'] / df['NET_REVENUE'] ) * 100

df['CM'] = df['KITCHEN_EBITDA']
df['CM_%'] = ( df['CM'] / df['NET_REVENUE'] ) * 100

df['EBITDA'] = df['KITCHEN_EBITDA']

# %%
sns.barplot(
    df,
    x=df['CITY'],
    y=df['NET_REVENUE']
)

plt.show()

# %%
sns.barplot(
    df,
    x=df['ZONE_MAPPING'],
    y=df['NET_REVENUE']
)

plt.show()

# %%
def barplot_with(col):
    sns.barplot(
        df,
        x=df[col],
        y=df['NET_REVENUE']
    )

    plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MONTH            2100 non-null   object
#  1   CITY             2100 non-null   object
#  2   STORE            2100 non-null   object
#  3   STATUS           2100 non-null   object
#  4   ZONE_MAPPING     2100 non-null   object
#  5   ORDER_COUNT      2100 non-null   int64
#  6   CART_SALES       2100 non-null   float64
#  7   DISCOUNT         2100 non-null   float64
#  8   NET_REVENUE      2100 non-null   float64
#  9   IDEAL_FOOD_COST  2100 non-null   float64
#  10  GROSS_MARGIN     2100 non-null   float64
#  11  KITCHEN_EBITDA   2100 non-null   float64
#  12  VARIANCE         2100 non-null   float64
#  13  REVENUE_COHORT   2100 non-null   object
#  14  CM_COHORT        2100 non-null   object
#  15  EBITDA_CATEGORY  2100 non-null   object
#  16  EBITDA_COHORT    2100 non-null   object
#  17  MONTH_NAME       2100 non-null   object
#  18  YEAR             2100 non-null   object
#  19  GM               2100 non-null   float64
#  20  GM_%             2100 non-null   float64
#  21  CM               2100 non-null   float64
#  22  CM_%             2100 non-null   float64
#  23  EBITDA           2100 non-null   float64
# dtypes: float64(12), int64(1), object(11)
# memory usage: 393.9+ KB

# %%
for col in ['REVENUE_COHORT','CM_COHORT', 'EBITDA_CATEGORY', 'EBITDA_COHORT', 'MONTH_NAME', 'YEAR']:
    barplot_with(col)

# %%
pd.pivot_table(
    df,
    values= [ "NET_REVENUE", "GM", "CM", "EBITDA" ],
    index= ["REVENUE_COHORT", "CM_COHORT", "EBITDA_CATEGORY", "EBITDA_COHORT"],
    columns=["MONTH_NAME", "YEAR"],
    aggfunc="sum",
    fill_value=0
)
# Out:
#                                                                         CM  \
# MONTH_NAME                                                             Dec
# YEAR                                                                  2023
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       1511061.38
#                                                 10% to 20%      3657967.17
#                                                 More than 20%   4110858.57
#                                 EBITDA -ve      0% to 10%       3285004.17
#                                                 10% to 20%      2520023.56
#                                                 More than 20%   6359965.10
#                   10% to 20%    EBITDA +ve      0% to 10%       3784270.91
#                                                 10% to 20%      2624229.99
#                                                 More than 20%   2924461.89
#                                 EBITDA -ve      0% to 10%       6203021.24
#                                                 10% to 20%     11364710.53
#                                                 More than 20%   4994573.40
#                   More than 30% EBITDA +ve      0% to 10%       3495072.10
#                                                 10% to 20%      5702067.43
#                                                 More than 20%   7308967.60
#                                 EBITDA -ve      0% to 10%       4563215.89
#                                                 10% to 20%      4454932.63
#                                                 More than 20%   3512837.93
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       5466114.44
#                                                 10% to 20%      2560507.02
#                                                 More than 20%   6337979.17
#                                 EBITDA -ve      0% to 10%       8037334.77
#                                                 10% to 20%      3194487.01
#                                                 More than 20%   4479856.89
#                   10% to 20%    EBITDA +ve      0% to 10%       3036119.83
#                                                 10% to 20%      3898929.64
#                                                 More than 20%    851086.09
#                                 EBITDA -ve      0% to 10%       9049800.18
#                                                 10% to 20%      3804823.11
#                                                 More than 20%   3082846.44
#                   More than 30% EBITDA +ve      0% to 10%       5524866.92
#                                                 10% to 20%      3813561.09
#                                                 More than 20%   5480943.81
#                                 EBITDA -ve      0% to 10%       1945988.02
#                                                 10% to 20%      3075282.24
#                                                 More than 20%   5137107.83
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%        175475.47
#                                                 10% to 20%      5042234.99
#                                                 More than 20%   3338442.40
#                                 EBITDA -ve      0% to 10%       7388811.56
#                                                 10% to 20%      3229401.73
#                                                 More than 20%   4447303.79
#                   10% to 20%    EBITDA +ve      0% to 10%       6064819.15
#                                                 10% to 20%      6131387.18
#                                                 More than 20%   3210687.03
#                                 EBITDA -ve      0% to 10%       4373943.16
#                                                 10% to 20%      4361864.09
#                                                 More than 20%    724820.69
#                   More than 30% EBITDA +ve      0% to 10%       2090924.65
#                                                 10% to 20%      2696905.96
#                                                 More than 20%   5965359.69
#                                 EBITDA -ve      0% to 10%       1910597.26
#                                                 10% to 20%      4725476.12
#                                                 More than 20%   4879931.22
#
#                                                                             \
# MONTH_NAME                                                             Feb
# YEAR                                                                  2024
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       5814592.26
#                                                 10% to 20%      1258120.18
#                                                 More than 20%   2637802.64
#                                 EBITDA -ve      0% to 10%       6127716.83
#                                                 10% to 20%      4653298.18
#                                                 More than 20%   2929504.24
#                   10% to 20%    EBITDA +ve      0% to 10%       1039495.03
#                                                 10% to 20%      4018663.94
#                                                 More than 20%   1570407.71
#                                 EBITDA -ve      0% to 10%       7552896.00
#                                                 10% to 20%      6920200.07
#                                                 More than 20%   4264871.35
#                   More than 30% EBITDA +ve      0% to 10%       3707775.83
#                                                 10% to 20%      3756117.78
#                                                 More than 20%   4639016.60
#                                 EBITDA -ve      0% to 10%       5108305.20
#                                                 10% to 20%      4588022.69
#                                                 More than 20%   5608676.58
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       4115344.02
#                                                 10% to 20%      4244310.74
#                                                 More than 20%   4904378.80
#                                 EBITDA -ve      0% to 10%       1745073.20
#                                                 10% to 20%      4134754.25
#                                                 More than 20%   5827030.44
#                   10% to 20%    EBITDA +ve      0% to 10%       1683753.91
#                                                 10% to 20%      2230518.73
#                                                 More than 20%   5518878.70
#                                 EBITDA -ve      0% to 10%       4719496.21
#                                                 10% to 20%      5636751.43
#                                                 More than 20%   4371323.84
#                   More than 30% EBITDA +ve      0% to 10%       1842491.78
#                                                 10% to 20%      3818951.15
#                                                 More than 20%   2987741.16
#                                 EBITDA -ve      0% to 10%       5898845.35
#                                                 10% to 20%      3612233.69
#                                                 More than 20%   6634060.94
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%        998192.09
#                                                 10% to 20%      5889726.04
#                                                 More than 20%   4482293.46
#                                 EBITDA -ve      0% to 10%       1826022.30
#                                                 10% to 20%      1823024.42
#                                                 More than 20%   3116964.71
#                   10% to 20%    EBITDA +ve      0% to 10%       6648680.16
#                                                 10% to 20%      1982443.38
#                                                 More than 20%   2646986.59
#                                 EBITDA -ve      0% to 10%      10908765.09
#                                                 10% to 20%      1098333.07
#                                                 More than 20%   3605704.97
#                   More than 30% EBITDA +ve      0% to 10%       5688767.42
#                                                 10% to 20%     13171018.62
#                                                 More than 20%   6784323.23
#                                 EBITDA -ve      0% to 10%       5444012.22
#                                                 10% to 20%      3092251.52
#                                                 More than 20%   4737328.37
#
#                                                                             \
# MONTH_NAME                                                             Jan
# YEAR                                                                  2024
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       2056208.31
#                                                 10% to 20%      3955809.94
#                                                 More than 20%   4214050.60
#                                 EBITDA -ve      0% to 10%       1459919.00
#                                                 10% to 20%      3655545.93
#                                                 More than 20%   1576894.61
#                   10% to 20%    EBITDA +ve      0% to 10%       2148886.72
#                                                 10% to 20%      8082376.90
#                                                 More than 20%   3694460.41
#                                 EBITDA -ve      0% to 10%       8972219.03
#                                                 10% to 20%     10675292.84
#                                                 More than 20%   8218681.72
#                   More than 30% EBITDA +ve      0% to 10%       2057509.51
#                                                 10% to 20%      5400471.52
#                                                 More than 20%   7580719.57
#                                 EBITDA -ve      0% to 10%      10345411.85
#                                                 10% to 20%      5076336.48
#                                                 More than 20%   9110795.19
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       4568039.36
#                                                 10% to 20%      5226151.55
#                                                 More than 20%   3541390.17
#                                 EBITDA -ve      0% to 10%        303084.57
#                                                 10% to 20%      2448718.03
#                                                 More than 20%   1057759.95
#                   10% to 20%    EBITDA +ve      0% to 10%       1698562.73
#                                                 10% to 20%       866189.02
#                                                 More than 20%   3952982.94
#                                 EBITDA -ve      0% to 10%       5544472.70
#                                                 10% to 20%      3042114.17
#                                                 More than 20%   5168488.92
#                   More than 30% EBITDA +ve      0% to 10%       5054673.90
#                                                 10% to 20%      4437044.71
#                                                 More than 20%   6858252.44
#                                 EBITDA -ve      0% to 10%       6837605.84
#                                                 10% to 20%      7816972.29
#                                                 More than 20%   2442116.34
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       7099918.73
#                                                 10% to 20%      3635560.56
#                                                 More than 20%   2009366.03
#                                 EBITDA -ve      0% to 10%       1771988.27
#                                                 10% to 20%      4243557.07
#                                                 More than 20%   3479857.71
#                   10% to 20%    EBITDA +ve      0% to 10%       7247087.83
#                                                 10% to 20%      3870860.68
#                                                 More than 20%   2983873.13
#                                 EBITDA -ve      0% to 10%       8690844.72
#                                                 10% to 20%      4781983.65
#                                                 More than 20%   1863747.50
#                   More than 30% EBITDA +ve      0% to 10%       6428954.47
#                                                 10% to 20%      3912740.18
#                                                 More than 20%   4918223.74
#                                 EBITDA -ve      0% to 10%       5844378.60
#                                                 10% to 20%      7122706.66
#                                                 More than 20%   5753998.97
#
#                                                                             \
# MONTH_NAME                                                             Mar
# YEAR                                                                  2024
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       6887398.26
#                                                 10% to 20%       899777.35
#                                                 More than 20%   1523666.32
#                                 EBITDA -ve      0% to 10%        397033.52
#                                                 10% to 20%      6870915.18
#                                                 More than 20%   7366677.15
#                   10% to 20%    EBITDA +ve      0% to 10%       5488967.57
#                                                 10% to 20%      3770304.35
#                                                 More than 20%   1961608.02
#                                 EBITDA -ve      0% to 10%       3720234.37
#                                                 10% to 20%      4553901.71
#                                                 More than 20%    481159.07
#                   More than 30% EBITDA +ve      0% to 10%       6953877.02
#                                                 10% to 20%      4380402.32
#                                                 More than 20%   1660795.35
#                                 EBITDA -ve      0% to 10%       1762352.66
#                                                 10% to 20%      5559333.43
#                                                 More than 20%   4240351.62
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       4410963.44
#                                                 10% to 20%      2678352.47
#                                                 More than 20%    448854.51
#                                 EBITDA -ve      0% to 10%       2635141.10
#                                                 10% to 20%      4630801.97
#                                                 More than 20%   5906452.04
#                   10% to 20%    EBITDA +ve      0% to 10%       1661955.08
#                                                 10% to 20%      3225774.37
#                                                 More than 20%   5911913.18
#                                 EBITDA -ve      0% to 10%       4660251.23
#                                                 10% to 20%      7870584.33
#                                                 More than 20%   8933756.64
#                   More than 30% EBITDA +ve      0% to 10%       1786155.84
#                                                 10% to 20%     11966367.62
#                                                 More than 20%   5045375.03
#                                 EBITDA -ve      0% to 10%       4344112.92
#                                                 10% to 20%      8039317.68
#                                                 More than 20%   2411555.77
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       5856418.14
#                                                 10% to 20%      4860332.84
#                                                 More than 20%   4269706.52
#                                 EBITDA -ve      0% to 10%       1522078.90
#                                                 10% to 20%      4296194.97
#                                                 More than 20%   3808584.45
#                   10% to 20%    EBITDA +ve      0% to 10%       6118126.98
#                                                 10% to 20%      5173291.61
#                                                 More than 20%   6932287.96
#                                 EBITDA -ve      0% to 10%       4151734.78
#                                                 10% to 20%      3887570.24
#                                                 More than 20%   6237995.63
#                   More than 30% EBITDA +ve      0% to 10%       2989380.98
#                                                 10% to 20%      5220042.36
#                                                 More than 20%   6582572.37
#                                 EBITDA -ve      0% to 10%       6067714.00
#                                                 10% to 20%      1478810.36
#                                                 More than 20%   2939717.66
#
#                                                                             \
# MONTH_NAME                                                             Nov
# YEAR                                                                  2023
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       5742570.11
#                                                 10% to 20%      3597127.92
#                                                 More than 20%   4350391.17
#                                 EBITDA -ve      0% to 10%       2034110.99
#                                                 10% to 20%      3947412.59
#                                                 More than 20%   4304804.37
#                   10% to 20%    EBITDA +ve      0% to 10%       3391688.92
#                                                 10% to 20%      3424651.31
#                                                 More than 20%   9049747.03
#                                 EBITDA -ve      0% to 10%       3071107.34
#                                                 10% to 20%      1662325.76
#                                                 More than 20%   6618068.50
#                   More than 30% EBITDA +ve      0% to 10%       5870776.71
#                                                 10% to 20%       870116.26
#                                                 More than 20%   3114915.28
#                                 EBITDA -ve      0% to 10%       7912177.29
#                                                 10% to 20%      3302196.68
#                                                 More than 20%   4154283.43
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       7993338.09
#                                                 10% to 20%      1825755.63
#                                                 More than 20%   5028277.92
#                                 EBITDA -ve      0% to 10%       3529003.23
#                                                 10% to 20%      4444272.46
#                                                 More than 20%   3992670.37
#                   10% to 20%    EBITDA +ve      0% to 10%       4077606.60
#                                                 10% to 20%      4089154.65
#                                                 More than 20%   4445096.47
#                                 EBITDA -ve      0% to 10%        975884.91
#                                                 10% to 20%      2118098.89
#                                                 More than 20%   5522725.10
#                   More than 30% EBITDA +ve      0% to 10%        437843.04
#                                                 10% to 20%      2755722.47
#                                                 More than 20%   4309195.39
#                                 EBITDA -ve      0% to 10%       4140943.74
#                                                 10% to 20%      3154353.15
#                                                 More than 20%   3473514.40
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       3992743.08
#                                                 10% to 20%      3766601.40
#                                                 More than 20%   1559825.55
#                                 EBITDA -ve      0% to 10%       3626564.62
#                                                 10% to 20%     10185843.39
#                                                 More than 20%   5044980.12
#                   10% to 20%    EBITDA +ve      0% to 10%       3500091.34
#                                                 10% to 20%      2311890.14
#                                                 More than 20%   2636917.99
#                                 EBITDA -ve      0% to 10%       6258687.03
#                                                 10% to 20%      5451827.70
#                                                 More than 20%   4302001.27
#                   More than 30% EBITDA +ve      0% to 10%       6606563.86
#                                                 10% to 20%      3136091.06
#                                                 More than 20%   3658095.63
#                                 EBITDA -ve      0% to 10%       7131748.02
#                                                 10% to 20%      8515111.26
#                                                 More than 20%   5099434.31
#
#                                                                            \
# MONTH_NAME                                                            Oct
# YEAR                                                                 2023
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%      3507560.44
#                                                 10% to 20%     5042871.30
#                                                 More than 20%  5757762.77
#                                 EBITDA -ve      0% to 10%      4748202.38
#                                                 10% to 20%     2888154.93
#                                                 More than 20%  6004759.22
#                   10% to 20%    EBITDA +ve      0% to 10%      4313072.37
#                                                 10% to 20%     5215485.28
#                                                 More than 20%  2953185.49
#                                 EBITDA -ve      0% to 10%      4924862.15
#                                                 10% to 20%     6817706.06
#                                                 More than 20%  2021055.66
#                   More than 30% EBITDA +ve      0% to 10%      3027754.15
#                                                 10% to 20%     3613295.29
#                                                 More than 20%  5447561.74
#                                 EBITDA -ve      0% to 10%      8979747.69
#                                                 10% to 20%     6119184.42
#                                                 More than 20%  4053460.78
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      5600682.77
#                                                 10% to 20%      293319.63
#                                                 More than 20%  5090135.64
#                                 EBITDA -ve      0% to 10%      6955065.25
#                                                 10% to 20%     3760364.13
#                                                 More than 20%  2757027.57
#                   10% to 20%    EBITDA +ve      0% to 10%      2332767.40
#                                                 10% to 20%     4711967.59
#                                                 More than 20%  3405382.67
#                                 EBITDA -ve      0% to 10%      4186112.69
#                                                 10% to 20%     4507607.66
#                                                 More than 20%  7836157.80
#                   More than 30% EBITDA +ve      0% to 10%      4316832.10
#                                                 10% to 20%     3411203.23
#                                                 More than 20%  4307297.46
#                                 EBITDA -ve      0% to 10%      4321152.45
#                                                 10% to 20%     6281862.77
#                                                 More than 20%  3777373.33
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      3684833.15
#                                                 10% to 20%     6862062.79
#                                                 More than 20%  3102428.59
#                                 EBITDA -ve      0% to 10%      9063502.29
#                                                 10% to 20%     4367367.22
#                                                 More than 20%  2441022.34
#                   10% to 20%    EBITDA +ve      0% to 10%      3436098.73
#                                                 10% to 20%     4709288.56
#                                                 More than 20%  4961743.95
#                                 EBITDA -ve      0% to 10%      4790974.08
#                                                 10% to 20%     2488263.09
#                                                 More than 20%  7684969.63
#                   More than 30% EBITDA +ve      0% to 10%      5361872.13
#                                                 10% to 20%     7465432.31
#                                                 More than 20%  3077230.53
#                                 EBITDA -ve      0% to 10%      3621274.12
#                                                 10% to 20%     9005419.21
#                                                 More than 20%   765170.58
#
#                                                                     EBITDA  \
# MONTH_NAME                                                             Dec
# YEAR                                                                  2023
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       1511061.38
#                                                 10% to 20%      3657967.17
#                                                 More than 20%   4110858.57
#                                 EBITDA -ve      0% to 10%       3285004.17
#                                                 10% to 20%      2520023.56
#                                                 More than 20%   6359965.10
#                   10% to 20%    EBITDA +ve      0% to 10%       3784270.91
#                                                 10% to 20%      2624229.99
#                                                 More than 20%   2924461.89
#                                 EBITDA -ve      0% to 10%       6203021.24
#                                                 10% to 20%     11364710.53
#                                                 More than 20%   4994573.40
#                   More than 30% EBITDA +ve      0% to 10%       3495072.10
#                                                 10% to 20%      5702067.43
#                                                 More than 20%   7308967.60
#                                 EBITDA -ve      0% to 10%       4563215.89
#                                                 10% to 20%      4454932.63
#                                                 More than 20%   3512837.93
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       5466114.44
#                                                 10% to 20%      2560507.02
#                                                 More than 20%   6337979.17
#                                 EBITDA -ve      0% to 10%       8037334.77
#                                                 10% to 20%      3194487.01
#                                                 More than 20%   4479856.89
#                   10% to 20%    EBITDA +ve      0% to 10%       3036119.83
#                                                 10% to 20%      3898929.64
#                                                 More than 20%    851086.09
#                                 EBITDA -ve      0% to 10%       9049800.18
#                                                 10% to 20%      3804823.11
#                                                 More than 20%   3082846.44
#                   More than 30% EBITDA +ve      0% to 10%       5524866.92
#                                                 10% to 20%      3813561.09
#                                                 More than 20%   5480943.81
#                                 EBITDA -ve      0% to 10%       1945988.02
#                                                 10% to 20%      3075282.24
#                                                 More than 20%   5137107.83
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%        175475.47
#                                                 10% to 20%      5042234.99
#                                                 More than 20%   3338442.40
#                                 EBITDA -ve      0% to 10%       7388811.56
#                                                 10% to 20%      3229401.73
#                                                 More than 20%   4447303.79
#                   10% to 20%    EBITDA +ve      0% to 10%       6064819.15
#                                                 10% to 20%      6131387.18
#                                                 More than 20%   3210687.03
#                                 EBITDA -ve      0% to 10%       4373943.16
#                                                 10% to 20%      4361864.09
#                                                 More than 20%    724820.69
#                   More than 30% EBITDA +ve      0% to 10%       2090924.65
#                                                 10% to 20%      2696905.96
#                                                 More than 20%   5965359.69
#                                 EBITDA -ve      0% to 10%       1910597.26
#                                                 10% to 20%      4725476.12
#                                                 More than 20%   4879931.22
#
#                                                                             \
# MONTH_NAME                                                             Feb
# YEAR                                                                  2024
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       5814592.26
#                                                 10% to 20%      1258120.18
#                                                 More than 20%   2637802.64
#                                 EBITDA -ve      0% to 10%       6127716.83
#                                                 10% to 20%      4653298.18
#                                                 More than 20%   2929504.24
#                   10% to 20%    EBITDA +ve      0% to 10%       1039495.03
#                                                 10% to 20%      4018663.94
#                                                 More than 20%   1570407.71
#                                 EBITDA -ve      0% to 10%       7552896.00
#                                                 10% to 20%      6920200.07
#                                                 More than 20%   4264871.35
#                   More than 30% EBITDA +ve      0% to 10%       3707775.83
#                                                 10% to 20%      3756117.78
#                                                 More than 20%   4639016.60
#                                 EBITDA -ve      0% to 10%       5108305.20
#                                                 10% to 20%      4588022.69
#                                                 More than 20%   5608676.58
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       4115344.02
#                                                 10% to 20%      4244310.74
#                                                 More than 20%   4904378.80
#                                 EBITDA -ve      0% to 10%       1745073.20
#                                                 10% to 20%      4134754.25
#                                                 More than 20%   5827030.44
#                   10% to 20%    EBITDA +ve      0% to 10%       1683753.91
#                                                 10% to 20%      2230518.73
#                                                 More than 20%   5518878.70
#                                 EBITDA -ve      0% to 10%       4719496.21
#                                                 10% to 20%      5636751.43
#                                                 More than 20%   4371323.84
#                   More than 30% EBITDA +ve      0% to 10%       1842491.78
#                                                 10% to 20%      3818951.15
#                                                 More than 20%   2987741.16
#                                 EBITDA -ve      0% to 10%       5898845.35
#                                                 10% to 20%      3612233.69
#                                                 More than 20%   6634060.94
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%        998192.09
#                                                 10% to 20%      5889726.04
#                                                 More than 20%   4482293.46
#                                 EBITDA -ve      0% to 10%       1826022.30
#                                                 10% to 20%      1823024.42
#                                                 More than 20%   3116964.71
#                   10% to 20%    EBITDA +ve      0% to 10%       6648680.16
#                                                 10% to 20%      1982443.38
#                                                 More than 20%   2646986.59
#                                 EBITDA -ve      0% to 10%      10908765.09
#                                                 10% to 20%      1098333.07
#                                                 More than 20%   3605704.97
#                   More than 30% EBITDA +ve      0% to 10%       5688767.42
#                                                 10% to 20%     13171018.62
#                                                 More than 20%   6784323.23
#                                 EBITDA -ve      0% to 10%       5444012.22
#                                                 10% to 20%      3092251.52
#                                                 More than 20%   4737328.37
#
#                                                                             \
# MONTH_NAME                                                             Jan
# YEAR                                                                  2024
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       2056208.31
#                                                 10% to 20%      3955809.94
#                                                 More than 20%   4214050.60
#                                 EBITDA -ve      0% to 10%       1459919.00
#                                                 10% to 20%      3655545.93
#                                                 More than 20%   1576894.61
#                   10% to 20%    EBITDA +ve      0% to 10%       2148886.72
#                                                 10% to 20%      8082376.90
#                                                 More than 20%   3694460.41
#                                 EBITDA -ve      0% to 10%       8972219.03
#                                                 10% to 20%     10675292.84
#                                                 More than 20%   8218681.72
#                   More than 30% EBITDA +ve      0% to 10%       2057509.51
#                                                 10% to 20%      5400471.52
#                                                 More than 20%   7580719.57
#                                 EBITDA -ve      0% to 10%      10345411.85
#                                                 10% to 20%      5076336.48
#                                                 More than 20%   9110795.19
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       4568039.36
#                                                 10% to 20%      5226151.55
#                                                 More than 20%   3541390.17
#                                 EBITDA -ve      0% to 10%        303084.57
#                                                 10% to 20%      2448718.03
#                                                 More than 20%   1057759.95
#                   10% to 20%    EBITDA +ve      0% to 10%       1698562.73
#                                                 10% to 20%       866189.02
#                                                 More than 20%   3952982.94
#                                 EBITDA -ve      0% to 10%       5544472.70
#                                                 10% to 20%      3042114.17
#                                                 More than 20%   5168488.92
#                   More than 30% EBITDA +ve      0% to 10%       5054673.90
#                                                 10% to 20%      4437044.71
#                                                 More than 20%   6858252.44
#                                 EBITDA -ve      0% to 10%       6837605.84
#                                                 10% to 20%      7816972.29
#                                                 More than 20%   2442116.34
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       7099918.73
#                                                 10% to 20%      3635560.56
#                                                 More than 20%   2009366.03
#                                 EBITDA -ve      0% to 10%       1771988.27
#                                                 10% to 20%      4243557.07
#                                                 More than 20%   3479857.71
#                   10% to 20%    EBITDA +ve      0% to 10%       7247087.83
#                                                 10% to 20%      3870860.68
#                                                 More than 20%   2983873.13
#                                 EBITDA -ve      0% to 10%       8690844.72
#                                                 10% to 20%      4781983.65
#                                                 More than 20%   1863747.50
#                   More than 30% EBITDA +ve      0% to 10%       6428954.47
#                                                 10% to 20%      3912740.18
#                                                 More than 20%   4918223.74
#                                 EBITDA -ve      0% to 10%       5844378.60
#                                                 10% to 20%      7122706.66
#                                                 More than 20%   5753998.97
#
#                                                                             \
# MONTH_NAME                                                             Mar
# YEAR                                                                  2024
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%       6887398.26
#                                                 10% to 20%       899777.35
#                                                 More than 20%   1523666.32
#                                 EBITDA -ve      0% to 10%        397033.52
#                                                 10% to 20%      6870915.18
#                                                 More than 20%   7366677.15
#                   10% to 20%    EBITDA +ve      0% to 10%       5488967.57
#                                                 10% to 20%      3770304.35
#                                                 More than 20%   1961608.02
#                                 EBITDA -ve      0% to 10%       3720234.37
#                                                 10% to 20%      4553901.71
#                                                 More than 20%    481159.07
#                   More than 30% EBITDA +ve      0% to 10%       6953877.02
#                                                 10% to 20%      4380402.32
#                                                 More than 20%   1660795.35
#                                 EBITDA -ve      0% to 10%       1762352.66
#                                                 10% to 20%      5559333.43
#                                                 More than 20%   4240351.62
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       4410963.44
#                                                 10% to 20%      2678352.47
#                                                 More than 20%    448854.51
#                                 EBITDA -ve      0% to 10%       2635141.10
#                                                 10% to 20%      4630801.97
#                                                 More than 20%   5906452.04
#                   10% to 20%    EBITDA +ve      0% to 10%       1661955.08
#                                                 10% to 20%      3225774.37
#                                                 More than 20%   5911913.18
#                                 EBITDA -ve      0% to 10%       4660251.23
#                                                 10% to 20%      7870584.33
#                                                 More than 20%   8933756.64
#                   More than 30% EBITDA +ve      0% to 10%       1786155.84
#                                                 10% to 20%     11966367.62
#                                                 More than 20%   5045375.03
#                                 EBITDA -ve      0% to 10%       4344112.92
#                                                 10% to 20%      8039317.68
#                                                 More than 20%   2411555.77
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%       5856418.14
#                                                 10% to 20%      4860332.84
#                                                 More than 20%   4269706.52
#                                 EBITDA -ve      0% to 10%       1522078.90
#                                                 10% to 20%      4296194.97
#                                                 More than 20%   3808584.45
#                   10% to 20%    EBITDA +ve      0% to 10%       6118126.98
#                                                 10% to 20%      5173291.61
#                                                 More than 20%   6932287.96
#                                 EBITDA -ve      0% to 10%       4151734.78
#                                                 10% to 20%      3887570.24
#                                                 More than 20%   6237995.63
#                   More than 30% EBITDA +ve      0% to 10%       2989380.98
#                                                 10% to 20%      5220042.36
#                                                 More than 20%   6582572.37
#                                 EBITDA -ve      0% to 10%       6067714.00
#                                                 10% to 20%      1478810.36
#                                                 More than 20%   2939717.66
#
#                                                                ...  \
# MONTH_NAME                                                     ...
# YEAR                                                           ...
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT  ...
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                                 EBITDA -ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                   10% to 20%    EBITDA +ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                                 EBITDA -ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                   More than 30% EBITDA +ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                                 EBITDA -ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                                 EBITDA -ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                   10% to 20%    EBITDA +ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                                 EBITDA -ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                   More than 30% EBITDA +ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
#                                 EBITDA -ve      0% to 10%      ...
#                                                 10% to 20%     ...
#                                                 More than 20%  ...
# ...
#                                                 More than 20%   7189308.67
#                   10% to 20%    EBITDA +ve      0% to 10%      11822434.18
#                                                 10% to 20%      6970708.79
#                                                 More than 20%  15275403.94
#                                 EBITDA -ve      0% to 10%      18595212.04
#                                                 10% to 20%     22869764.84
#                                                 More than 20%  23054930.44
#                   More than 30% EBITDA +ve      0% to 10%      29875315.11
#                                                 10% to 20%     22884713.35
#                                                 More than 20%  24301464.77
#                                 EBITDA -ve      0% to 10%      30431550.27
#                                                 10% to 20%     35424922.81
#                                                 More than 20%  13412948.78
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      35030324.88
#                                                 10% to 20%     18613189.63
#                                                 More than 20%  10490712.84
#                                 EBITDA -ve      0% to 10%      10027281.72
#                                                 10% to 20%     18113610.92
#                                                 More than 20%  20220850.86
#                   10% to 20%    EBITDA +ve      0% to 10%      30328648.44
#                                                 10% to 20%     23902998.98
#                                                 More than 20%  11268117.39
#                                 EBITDA -ve      0% to 10%      36478453.02
#                                                 10% to 20%     21787894.27
#                                                 More than 20%  16087497.30
#                   More than 30% EBITDA +ve      0% to 10%      36377391.08
#                                                 10% to 20%     29999202.80
#                                                 More than 20%  23545308.95
#                                 EBITDA -ve      0% to 10%      25373290.71
#                                                 10% to 20%     33100665.58
#                                                 More than 20%  29367921.56
#
#                                                                             \
# MONTH_NAME                                                             Mar
# YEAR                                                                  2024
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%      30812345.07
#                                                 10% to 20%      6884374.34
#                                                 More than 20%   7037980.85
#                                 EBITDA -ve      0% to 10%       8437961.64
#                                                 10% to 20%     26873040.09
#                                                 More than 20%  31227384.55
#                   10% to 20%    EBITDA +ve      0% to 10%      27979599.97
#                                                 10% to 20%     22224033.38
#                                                 More than 20%  12428545.05
#                                 EBITDA -ve      0% to 10%      14414312.24
#                                                 10% to 20%     16747394.13
#                                                 More than 20%  16830578.42
#                   More than 30% EBITDA +ve      0% to 10%      21533733.23
#                                                 10% to 20%     23104842.08
#                                                 More than 20%  13105238.76
#                                 EBITDA -ve      0% to 10%      12939012.38
#                                                 10% to 20%     32105618.36
#                                                 More than 20%  16460777.08
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      21657049.17
#                                                 10% to 20%     18718692.46
#                                                 More than 20%   5206796.38
#                                 EBITDA -ve      0% to 10%      16547842.47
#                                                 10% to 20%     17216953.60
#                                                 More than 20%  30719213.10
#                   10% to 20%    EBITDA +ve      0% to 10%      16443191.40
#                                                 10% to 20%     17651801.87
#                                                 More than 20%  36428627.31
#                                 EBITDA -ve      0% to 10%      25613566.36
#                                                 10% to 20%     31161173.52
#                                                 More than 20%  33692754.62
#                   More than 30% EBITDA +ve      0% to 10%      17040368.22
#                                                 10% to 20%     53277624.42
#                                                 More than 20%  23662684.25
#                                 EBITDA -ve      0% to 10%      17934600.45
#                                                 10% to 20%     35542811.27
#                                                 More than 20%  15571442.14
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      36116426.88
#                                                 10% to 20%     21694294.88
#                                                 More than 20%  26980396.02
#                                 EBITDA -ve      0% to 10%       6820576.90
#                                                 10% to 20%     23336726.74
#                                                 More than 20%  18062846.39
#                   10% to 20%    EBITDA +ve      0% to 10%      34965502.33
#                                                 10% to 20%     17322722.64
#                                                 More than 20%  33641515.45
#                                 EBITDA -ve      0% to 10%      23913848.74
#                                                 10% to 20%     17854341.84
#                                                 More than 20%  45041551.11
#                   More than 30% EBITDA +ve      0% to 10%      16909769.91
#                                                 10% to 20%     25228912.36
#                                                 More than 20%  38445976.74
#                                 EBITDA -ve      0% to 10%      31280785.29
#                                                 10% to 20%     19787155.49
#                                                 More than 20%  20298455.56
#
#                                                                             \
# MONTH_NAME                                                             Nov
# YEAR                                                                  2023
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%      24256537.57
#                                                 10% to 20%     21674832.93
#                                                 More than 20%  21785942.66
#                                 EBITDA -ve      0% to 10%      13244992.11
#                                                 10% to 20%     22569247.60
#                                                 More than 20%  24966247.21
#                   10% to 20%    EBITDA +ve      0% to 10%      21280795.85
#                                                 10% to 20%     16685182.88
#                                                 More than 20%  43739444.36
#                                 EBITDA -ve      0% to 10%      15502037.24
#                                                 10% to 20%     16646659.58
#                                                 More than 20%  35063350.38
#                   More than 30% EBITDA +ve      0% to 10%      23109902.12
#                                                 10% to 20%     11277250.06
#                                                 More than 20%  21037251.84
#                                 EBITDA -ve      0% to 10%      35995285.91
#                                                 10% to 20%     13937325.49
#                                                 More than 20%  17719974.99
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      32560032.71
#                                                 10% to 20%      7519137.90
#                                                 More than 20%  23159290.92
#                                 EBITDA -ve      0% to 10%      17827597.45
#                                                 10% to 20%     28045804.60
#                                                 More than 20%  23673515.46
#                   10% to 20%    EBITDA +ve      0% to 10%      18852196.04
#                                                 10% to 20%     20827262.92
#                                                 More than 20%  22063335.81
#                                 EBITDA -ve      0% to 10%      10970799.78
#                                                 10% to 20%     15522214.28
#                                                 More than 20%  17692680.53
#                   More than 30% EBITDA +ve      0% to 10%       5469404.62
#                                                 10% to 20%     12433169.29
#                                                 More than 20%  23884928.35
#                                 EBITDA -ve      0% to 10%      27797724.28
#                                                 10% to 20%     17278740.63
#                                                 More than 20%  24523302.98
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      19539958.20
#                                                 10% to 20%     18329115.69
#                                                 More than 20%  10602026.90
#                                 EBITDA -ve      0% to 10%      20952742.28
#                                                 10% to 20%     46766597.66
#                                                 More than 20%  26982560.00
#                   10% to 20%    EBITDA +ve      0% to 10%      16452650.51
#                                                 10% to 20%     10818478.28
#                                                 More than 20%  20153785.55
#                                 EBITDA -ve      0% to 10%      37678399.62
#                                                 10% to 20%     29205430.40
#                                                 More than 20%  27366204.04
#                   More than 30% EBITDA +ve      0% to 10%      26901437.89
#                                                 10% to 20%     22256560.52
#                                                 More than 20%  24047109.72
#                                 EBITDA -ve      0% to 10%      33358462.25
#                                                 10% to 20%     41220667.03
#                                                 More than 20%  32144952.76
#
#
# MONTH_NAME                                                             Oct
# YEAR                                                                  2023
# REVENUE_COHORT    CM_COHORT     EBITDA_CATEGORY EBITDA_COHORT
# INR 20 to 30 lacs 0% to 10%     EBITDA +ve      0% to 10%      11965132.22
#                                                 10% to 20%     19915023.82
#                                                 More than 20%  22622544.39
#                                 EBITDA -ve      0% to 10%      20155891.27
#                                                 10% to 20%     24485306.93
#                                                 More than 20%  29570757.64
#                   10% to 20%    EBITDA +ve      0% to 10%      19535859.78
#                                                 10% to 20%     20785831.36
#                                                 More than 20%  14326524.70
#                                 EBITDA -ve      0% to 10%      21373013.13
#                                                 10% to 20%     27195701.23
#                                                 More than 20%  16014479.79
#                   More than 30% EBITDA +ve      0% to 10%      16579306.95
#                                                 10% to 20%     15499402.57
#                                                 More than 20%  27383456.96
#                                 EBITDA -ve      0% to 10%      41759859.69
#                                                 10% to 20%     30745980.65
#                                                 More than 20%  22872556.34
# INR 30 to 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      19376265.39
#                                                 10% to 20%      8265646.24
#                                                 More than 20%  28899952.63
#                                 EBITDA -ve      0% to 10%      34702493.40
#                                                 10% to 20%     16522880.32
#                                                 More than 20%  13302535.07
#                   10% to 20%    EBITDA +ve      0% to 10%      17885302.41
#                                                 10% to 20%     29020285.15
#                                                 More than 20%  17835204.40
#                                 EBITDA -ve      0% to 10%      31169092.24
#                                                 10% to 20%     20418603.09
#                                                 More than 20%  32991108.03
#                   More than 30% EBITDA +ve      0% to 10%      36600593.07
#                                                 10% to 20%     16699207.77
#                                                 More than 20%  15970512.53
#                                 EBITDA -ve      0% to 10%      25113013.45
#                                                 10% to 20%     34685379.56
#                                                 More than 20%  25920311.21
# More than 40 lacs 0% to 10%     EBITDA +ve      0% to 10%      17914721.81
#                                                 10% to 20%     37908377.60
#                                                 More than 20%  11741256.62
#                                 EBITDA -ve      0% to 10%      34656734.42
#                                                 10% to 20%     19809550.77
#                                                 More than 20%  16034461.29
#                   10% to 20%    EBITDA +ve      0% to 10%      17853040.96
#                                                 10% to 20%     24783115.12
#                                                 More than 20%  23951098.21
#                                 EBITDA -ve      0% to 10%      18829099.12
#                                                 10% to 20%     12443995.73
#                                                 More than 20%  30991876.55
#                   More than 30% EBITDA +ve      0% to 10%      27677015.81
#                                                 10% to 20%     33789129.01
#                                                 More than 20%  23640732.54
#                                 EBITDA -ve      0% to 10%      15239923.79
#                                                 10% to 20%     33545674.91
#                                                 More than 20%  11734918.36
#
# [54 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['MONTH', 'CITY', 'STORE', 'STATUS', 'ZONE_MAPPING', 'ORDER_COUNT',
#        'CART_SALES', 'DISCOUNT', 'NET_REVENUE', 'IDEAL_FOOD_COST',
#        'GROSS_MARGIN', 'KITCHEN_EBITDA', 'VARIANCE', 'REVENUE_COHORT',
#        'CM_COHORT', 'EBITDA_CATEGORY', 'EBITDA_COHORT', 'MONTH_NAME', 'YEAR',
#        'GM', 'GM_%', 'CM', 'CM_%', 'EBITDA'],
#       dtype='object')

# %%
df['VARIANCE'].describe()
# Out:
# count     2100.000000
# mean     20176.588981
# std       5783.204330
# min      10018.480000
# 25%      15494.855000
# 50%      20195.190000
# 75%      25180.827500
# max      29993.940000
# Name: VARIANCE, dtype: float64

# %%
bins = [10019, 15495, 20195, 25181, 29994]

labels = ['Low', 'Medium-Low', 'Medium-High', 'High']

# Apply pd.cut to your column
df['VARIANCE_CATEGORY'] = pd.cut(df['VARIANCE'], bins=bins, labels=labels, include_lowest=True)

# %%
variance_pivot_table =  pd.pivot_table(
    df,
    values="VARIANCE",
    index="REVENUE_COHORT",
    columns=["YEAR", "MONTH_NAME"],
    aggfunc="sum",
    fill_value=0
)

variance_pivot_table
# Out:
# YEAR                     2023                                2024              \
# MONTH_NAME                Dec         Nov         Oct         Feb         Jan
# REVENUE_COHORT
# INR 20 to 30 lacs  2408134.56  2325049.84  2216665.71  2369531.16  2725338.58
# INR 30 to 40 lacs  2542138.16  2068259.28  2409058.60  2400828.73  1896294.66
# More than 40 lacs  2179570.87  2709732.64  2201795.29  2397678.36  2549149.93
#
# YEAR
# MONTH_NAME                Mar
# REVENUE_COHORT
# INR 20 to 30 lacs  1840250.46
# INR 30 to 40 lacs  2461400.45
# More than 40 lacs  2669959.58

# %%
pd.DataFrame(
    variance_pivot_table.sum(axis=0)
).T
# Out:
# YEAR              2023                               2024              \
# MONTH_NAME         Dec         Nov        Oct         Feb         Jan
# 0           7129843.59  7103041.76  6827519.6  7168038.25  7170783.17
#
# YEAR
# MONTH_NAME         Mar
# 0           6971610.49

# %%
# store count

store_count_table =  pd.pivot_table(
    df,
    values="STORE",
    index="VARIANCE_CATEGORY",
    columns=["YEAR", "MONTH_NAME"],
    aggfunc="count",
    fill_value=0,
    observed=True
)

store_count_table
# Out:
# YEAR              2023           2024
# MONTH_NAME         Dec  Nov  Oct  Feb Jan Mar
# VARIANCE_CATEGORY
# Low                 75   83  108   73  86  99
# Medium-Low          98   83   83   97  87  77
# Medium-High         89  101   78   86  82  89
# High                87   83   81   94  95  85

# %%
pd.DataFrame(
    store_count_table.sum(axis=0)
).T
# Out:
# YEAR       2023           2024
# MONTH_NAME  Dec  Nov  Oct  Feb  Jan  Mar
# 0           349  350  350  350  350  350

# %%
print(df.head(2).T)
# Out:
#                                    0                  1
# MONTH                       Oct-2023           Nov-2023
# CITY                       Ahmedabad          Ahmedabad
# STORE                   Ramos-Martin       Ramos-Martin
# STATUS                      Inactive           Inactive
# ZONE_MAPPING                    West               West
# ORDER_COUNT                    14270               8528
# CART_SALES                6554333.68         2637625.82
# DISCOUNT                  1163493.98          636015.27
# NET_REVENUE               5434068.17         2146679.55
# IDEAL_FOOD_COST           1763679.62           638415.3
# GROSS_MARGIN              3614747.39          1414249.0
# KITCHEN_EBITDA            2374914.55          151761.82
# VARIANCE                    29664.62           11769.85
# REVENUE_COHORT     INR 20 to 30 lacs  INR 20 to 30 lacs
# CM_COHORT                  0% to 10%      More than 30%
# EBITDA_CATEGORY           EBITDA +ve         EBITDA +ve
# EBITDA_COHORT          More than 20%      More than 20%
# MONTH_NAME                       Oct                Nov
# YEAR                            2023               2023
# GM                        3614747.39          1414249.0
# GM_%                       66.520096          65.880769
# CM                        2374914.55          151761.82
# CM_%                       43.704173           7.069608
# EBITDA                    2374914.55          151761.82
# VARIANCE_CATEGORY               High                Low

# %%
print(df.drop(columns={'MONTH', 'GROSS_MARGIN', 'KITCHEN_EBITDA'}))
# Out:
#         CITY         STORE    STATUS ZONE_MAPPING  ORDER_COUNT  CART_SALES  \
# 0  Ahmedabad  Ramos-Martin  Inactive         West        14270  6554333.68
# 1  Ahmedabad  Ramos-Martin  Inactive         West         8528  2637625.82
#
#      DISCOUNT  NET_REVENUE  IDEAL_FOOD_COST  VARIANCE  ...      CM_COHORT  \
# 0  1163493.98   5434068.17       1763679.62  29664.62  ...      0% to 10%
# 1   636015.27   2146679.55        638415.30  11769.85  ...  More than 30%
#
#   EBITDA_CATEGORY  EBITDA_COHORT MONTH_NAME  YEAR          GM       GM_%  \
# 0      EBITDA +ve  More than 20%        Oct  2023  3614747.39  66.520096
# 1      EBITDA +ve  More than 20%        Nov  2023  1414249.00  65.880769
#
#            CM       CM_%      EBITDA
# 0  2374914.55  43.704173  2374914.55
# 1   151761.82   7.069608   151761.82
#
# [2 rows x 21 columns]
